# %%
from os.path import dirname, abspath,join
import numpy as np
import pandas as pd
import json
from omegaconf import OmegaConf
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
df_loo = pd.read_csv("../experiments/evaluations/leave_one_out/df_loo.csv")
df_loo_old = pd.read_csv("../experiments/evaluations/leave_one_out/df_loo_old.csv")
df_loo_old2 = pd.read_csv("../experiments/evaluations/leave_one_out/df_loo_old2.csv")
df_loo_new = pd.read_csv("../experiments/evaluations/leave_one_out/df_loo_new.csv")
df_loo_new_new = pd.read_csv("../experiments/evaluations/leave_one_out/df_loo_new_new.csv")
